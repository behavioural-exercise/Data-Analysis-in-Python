# %%
import requests
import pandas as pd
import plotly.graph_objects as go
import numpy as np

# %%
market = pd.read_csv('market2021.csv', sep=';', index_col=False)
market.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 33 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Question                         58 non-null     object
#  1   Albania                          42 non-null     float64
#  2   Austria                          55 non-null     float64
#  3   Belgium                          52 non-null     float64
#  4   Bulgaria                         43 non-null     float64
#  5   Croatia                          53 non-null     float64
#  6   Cyprus                           54 non-null     float64
#  7   Denmark                          42 non-null     float64
#  8   Estonia                          51 non-null     float64
#  9   Finland                          49 non-null     float64
#  10  France                           53 non-null     float64
#  11  Germany                          56 non-null     float64
# ...

# %%
rwb = pd.read_csv('rwb2022.csv', sep=';')
rwb.head()
# Out:
#    ISO  Score  Rank Political Context  Rank_Pol Economic Context  Rank_Eco  \
# 0  NOR  92,65     1             94,89         1            90,38         1
# 1  DNK  90,27     2             94,34         2            83,67         3
# 2  SWE  88,84     3             91,96         3            87,66         2
# 3  EST  88,83     4             91,11         5            81,97         6
# 4  FIN  88,42     5              90,4         6            82,03         5
#
#   Legal Context  Rank_Leg Social Context  ...  Rank_Saf  \
# 0         92,23         1          93,71  ...        11
# 1         89,18         4          91,17  ...         7
# 2         90,27         3          90,18  ...        32
# 3         87,87         5             90  ...         6
# 4         86,64         9          90,77  ...        10
#
#                      Zone  Country_EN Country_FR Country_ES Country_AR  \
# 0  Europe - Asie centrale      Norway    Norvège    Noruega    النرويج
# ...

# %%
ecountries_rwb = []
for i in rwb[rwb.Zone == 'Europe - Asie centrale'].Country_EN.items():
    ecountries_rwb.append(i[1])
ecountries_rwb
# Out:
# ['Norway',
#  'Denmark',
#  'Sweden',
#  'Estonia',
#  'Finland',
#  'Ireland',
#  'Portugal',
#  'Lithuania',
#  'Liechtenstein',
#  'Switzerland',
#  'Iceland',
#  'Germany',
#  'Czech Republic',
#  'Luxembourg',
#  'Latvia',
#  'Belgium',
#  'United Kingdom',
#  'France',
#  'Slovakia',
#  'Netherlands',
#  'Austria',
#  'Spain',
#  'Moldova',
#  'Croatia',
#  'Armenia',
#  'Andorra',
#  'Slovenia',
#  'Romania',
#  'North Macedonia',
#  'Italy',
#  'Kosovo',
#  'Montenegro',
#  'Cyprus',
#  'Poland',
#  'Bosnia and Herzegovina',
#  'Kyrgyzstan',
#  'Malta',
#  'Serbia',
#  'Cyprus North',
#  'Hungary',
#  'Georgia',
#  'Bulgaria',
#  'Albania',
#  'Ukraine',
#  'Greece',
#  'Kazakhstan',
#  'Uzbekistan',
#  'Turkey',
#  'Tajikistan',
#  'Belarus',
#  'Azerbaijan',
#  'Russian Federation',
#  'Turkmenistan']

# %%
a = []
b = []
for country in rwb[rwb.Zone == 'Europe - Asie centrale'].Country_EN:
    if i in market.columns:
        a.append(i)
    elif i == 'Czech Republic':
        a.append('The Czech Republic')
    elif i == 'Netherlands':
        a.append('The Netherlands')
    elif i == 'North Macedonia':
        a.append('The Republic of North Macedonia')
    else:
        b.append(i)

# %%
market.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 33 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Question                         58 non-null     object
#  1   Albania                          42 non-null     float64
#  2   Austria                          55 non-null     float64
#  3   Belgium                          52 non-null     float64
#  4   Bulgaria                         43 non-null     float64
#  5   Croatia                          53 non-null     float64
#  6   Cyprus                           54 non-null     float64
#  7   Denmark                          42 non-null     float64
#  8   Estonia                          51 non-null     float64
#  9   Finland                          49 non-null     float64
#  10  France                           53 non-null     float64
#  11  Germany                          56 non-null     float64
# ...
